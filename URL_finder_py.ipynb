# %%
from bs4 import BeautifulSoup
import urllib3
from urllib.error import HTTPError
import re
from googlesearch import search 
import pandas as pd
from mechanize import Browser
import socket ### checking the internet connection
import requests


def f1(query):
    lii = []
    for j in search(query, num=20, stop=20, pause=2): 
        lii.append(j)
    return(lii)

###############################################

vec = [input()]

###############################################

for d in range(len(vec)):
    nq = []
    search1 = vec[d]
    regex = re.compile('[^a-zA-Z0-9]')
    search1 = regex.sub(' ',search1)
    search2 = search1.split(" ")
    search2 = [x for x in search2 if x != ""]
    search3 = []
    for i in range(len(search2)):
        search3.append(' '.join(filter(str.isalnum, search2[i][0])))
    #search3 = str(search3).strip("[]|''")
    ss = []
    ss = f1(search1)
    if ss == []:
        nq = "no result"
    else:
        nq = ss
        
#################################################

r = re.compile(".*linkedin.com|.*twitter|.*owler|.*youtube|.*manta.com|.*cbinsights.com|.*opensecrets.org|.*pitchbook.com|.*buzzfile.com|.*massinvestordatabase.com|.*bciq.biocentury.com|.*google|.*youtube|.*wikipedia|.*www.eu-startups|.*btech.eu|.*facebook|.*finance.yahoo.com|.*business.site|.*github.io|.*newswire.com|.*cutestat.com|.*wlinkedin.com|.*bloomberg.com|.*deutsche-startups.de|.*marketwatch.com|.*[.]ft.com|.*money.cnn.com|.*wsj.com|.*economist.com|.*getrichslowly.org|.*twitter.com|.*crunchbase.com|.*xing|.*github.com|.*workable.com|.*glassdoor|.*startupgermany|.*berlinstartupjobs|.*jobs|.*https://shop.|.*https://job.",re.IGNORECASE)
newlist = list(filter(r.match,nq))

nq1 = [x for x in nq if x not in newlist]

from tld import get_tld 
domain = []
for i in nq1:
    info = get_tld(i, as_object=True) 
    domain.append(info.domain)

domain1 =[]
for u in range(len(domain)):
    domain1.append(regex.sub(' ',domain[u]))
domain2 = []
for p in  range(len(domain1)):
    domain2.append(''.join(str(i) for i in domain1[p].split(" ")))

##################################################

aa1 = []
aa2 = []
if list(filter(re.compile(r'^'+''.join(str(i) for i in search1.split(" ")), re.IGNORECASE).match, domain2)) != []:
    r1 = re.compile(r'^'+''.join(str(i) for i in search1.split(" "))+'$', re.IGNORECASE)
    newlist1 = list(filter(r1.match,  domain2))
    if newlist1 == []:
        r2 = re.compile(r'^'+''.join(str(i) for i in search1.split(" ")), re.IGNORECASE)
        newlist2 = list(filter(r2.match, domain2))
        
        aa1 = newlist2
        aa2 = "exact match"
    else:
        
        aa1 = newlist1
        aa2 = "exact match+"
        
elif   list(filter(re.compile(search2[0], re.IGNORECASE).findall, domain2)) != []:
    if len(search2)>2:
        newlist3=[]
        for z in range(len(search2)):
            if z < (len(search2) - 1):
                if list(filter(re.compile(r'^'+''.join(str(i) for i in search2[:len(search2)-z]), re.IGNORECASE).match, domain2)) != []:
                    r3 = re.compile(r'^'+''.join(str(i) for i in search2[:len(search2)-z]), re.IGNORECASE)
                    newlist3 = list(filter(r3.match, domain2))
                    
                    aa1 = newlist3
                    aa2 = ("semi match -",z)
                    if newlist3 != []:
                        break 
        
                
            elif z == (len(search2) -1) and newlist3==[] :
                if list(filter(re.compile(r'^'+''.join(str(i) for i in search3), re.IGNORECASE).match, domain2)) != []:
                    r4 = re.compile(r'^'+''.join(str(i) for i in search3)+'$', re.IGNORECASE)
                    newlist4 = list(filter(r4.match,  domain2))
                    if newlist4 == []:
                        r5 = re.compile(r'^'+''.join(str(i) for i in search3), re.IGNORECASE)
                        newlist5 = list(filter(r5.match, domain2))
                        
                        aa1 = newlist5
                        aa2 = "fullletter"
                    else:
                        
                        aa1 = newlist4
                        aa2 = "fullletter+"
                else:
                    r6 = re.compile(search2[0], re.IGNORECASE)
                    newlist6 = list(filter(r6.findall, domain2))
                    
                    aa1 = newlist6
                    aa2 = "semi match+1"
    
    elif len(search2)==2:
        
        if list(filter(re.compile(r'^'+''.join(str(i) for i in search3)+'$', re.IGNORECASE).match, domain2)) != []:
            r7 = re.compile(r'^'+''.join(str(i) for i in search3)+'$', re.IGNORECASE)
            newlist7 = list(filter(r7.match,  domain2))
            
            aa1 = newlist7
            aa2 = "fullletter+"
        else:
            r8 = re.compile(search2[0], re.IGNORECASE)
            newlist8 = list(filter(r8.findall, domain2))        
               
            aa1 = newlist8
            aa2 = "semi match+1"
    
    else:
        
        r8a = re.compile(search2[0], re.IGNORECASE)
        newlist8a = list(filter(r8a.findall, domain2))        
               
        aa1 = newlist8a
        aa2 = "semi match+1"
        
    
else:
    if list(filter(re.compile(r'^'+''.join(str(i) for i in search3)+'$', re.IGNORECASE).match, domain2)) != []:
        
        r9 = re.compile(r'^'+''.join(str(i) for i in search3)+'$', re.IGNORECASE)
        newlist9 = list(filter(r9.match,  domain2))
        
        aa1 = newlist9
        aa2 = "fullletter+"
    
    elif len(search3)>2:
        newlist10=[]
        for z in range(len(search3)):
            
            if z < (len(search3) - 1):
                if list(filter(re.compile(r'^'+''.join(str(i) for i in search3[:len(search3)-z]), re.IGNORECASE).match, domain2)) != []:
                    r10 = re.compile(r'^'+''.join(str(i) for i in search3[:len(search3)-z]), re.IGNORECASE)
                    newlist10 = list(filter(r10.match, domain2))
                    
                    aa1 =  newlist10
                    aa2 = ("semi match letter -",z)
                    if newlist10 != []:
                        break    
            
            
            elif z == (len(search3) -1) and newlist10==[]:
                if list(filter(re.compile(r'^'+''.join(str(i) for i in search3), re.IGNORECASE).match, domain2)) != []:
                    r11 = re.compile(r'^'+''.join(str(i) for i in search3)+'$', re.IGNORECASE)
                    newlist11 = list(filter(r11.match,  domain2))
                    if newlist11 == []:
                        r12 = re.compile(r'^'+''.join(str(i) for i in search3), re.IGNORECASE)
                        newlist12 = list(filter(r12.match, domain2))
                        
                        aa1 = newlist12
                        aa2 = "fullletter"
                    else:
                        
                        aa1 = newlist11
                        aa2 = "fullletter+"
                else:
                    
                     
                    aa1 = []
                    aa2 = ("no result")
                    
    elif len(search3)==2:
        
        if list(filter(re.compile(r'^'+''.join(str(i) for i in search3)+'$', re.IGNORECASE).match, domain2)) != []:
            r13 = re.compile(r'^'+''.join(str(i) for i in search3)+'$', re.IGNORECASE)
            newlist13 = list(filter(r13.match,  domain2))
            
            aa1 = newlist13
            aa2 = "fullletter+"
        else:       
            
            aa1 = []
            aa2 = "no result"
    else:
        
        aa1 = []
        aa2 = "no result"

indexes = [] 
for m in range(len(aa1)):
    ind = [i for i,val in enumerate(domain2) if val==aa1[m]]
    indexes.append(ind)
if indexes == []:
    result1 = "-"
    result2 = aa2

else:
    domres = []
    for m in range(len(indexes)):
        for n in range(len(indexes[m])):
            domres.append(nq1[indexes[m][n]])
    le = []
    for u in range(len(domres)):
        le.append(len(domres[u]))        
    result1 = [num for num in domres if len(num) == min(le)][0]
    result2 = aa2


if result2 == "no result":
    result3 = "-"
else:
    
    #try:
        #br = Browser()
        #br.open(result1)
        #result3 = br.title()
    #except HTTPError as ee:
        #result3 = "-"
    
    try:
        #br = Browser()
        #br.open(result1)
        #result3 = br.title()
        
        result3 = BeautifulSoup(requests.get(result1).content).title.string
        result3 = re.sub(r'[\t]|[\r]|[\n]|[\x8f]', '', result3)
    except :
        result3 = "-"
    
if result3 == "-":
    result4 = "-"
else:
    if bool(re.search(str(vec).strip("[]|''"), result3,re.IGNORECASE))|bool(re.search(result3,str(vec).strip("[]|''"),re.IGNORECASE))|bool(re.search(str(''.join(str(i) for i in search1.split(" "))).strip("[]|''"), result3,re.IGNORECASE))|bool(re.search(result3,str(''.join(str(i) for i in search1.split(" "))).strip("[]|''"),re.IGNORECASE)):
        result4 = "fine"
    else:
        result4 = "check"
        

print("Name: "+str(vec).strip("[]|''"))
print("URL: "+result1)
print("Logic: "+str(result2).strip("[]|(|)"))
print("HTMLTitle: "+result3)
print("Check: "+result4)
